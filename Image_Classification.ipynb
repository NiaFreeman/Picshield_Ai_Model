# %% [markdown]
# # Image Classification (sanitized)
#
# This notebook is a sanitized, public-friendly copy. All execution outputs were removed and editor-specific metadata was stripped. The original file is available as `Image_Classification.ipynb.bak`.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
IMG_SIZE = 160
BATCH_SIZE = 32
EPOCHS = 10
git_folder = '/content/Detection-of-Sensitive-Data-Exposure-in-Images'
dataset_folder = git_folder + '/dataset/'
