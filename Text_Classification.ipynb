# %% [markdown]
# # Text Classification (sanitized)
#
# This notebook is a sanitized, public-friendly copy. All execution outputs were removed and editor-specific metadata was stripped. The original file is available as `Text_Classification.ipynb.bak`.

# %%
import tensorflow as tf
import json, os, random
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

git_folder = '/content/Detection-of-Sensitive-Data-Exposure-in-Images'
dataset_folder = git_folder + '/text_dataset/'
